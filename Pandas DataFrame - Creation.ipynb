# %% [markdown]
# <h1 style = "color:Red">pandas.DataFrame</h1>
#
#
#
# <h2 style = "color:Green">
#
# * Two dimensional data structure
#
#
# * Used to store tabular data --> rows and column with row index and column index
#
#
# * Each column can have different type of data.
#
#
# * We can think of it like a spreadsheet or database table.</h2>
#
#
# ![New%20Microsoft%20PowerPoint%20Presentation.png](attachment:New%20Microsoft%20PowerPoint%20Presentation.png)

# %%
# Import pandas
import pandas as pd

# %% [markdown]
# <h2 style = "color:Green">DataFrame Creation</h2>

# %% [markdown]
# <h3 style = "color:Blue">Creation of Empty DataFrame</h3>

# %%
dfempty = pd.DataFrame()
print(dfempty)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# <h3 style = "color:Blue">Creation of DataFrame from dictionary of lists</h3>

# %%
dict1 = {"Name":["Ramu","Rani","Raju"], "Age":[35, 45, 65], "Percentage":[67.5,89.6,98.7]}
# Here each item(key:value pair) wiil be a column in the dataframe

df1 = pd.DataFrame(dict1)

print(df1)
# Out:
#    Name  Age  Percentage
# 0  Ramu   35        67.5
# 1  Rani   45        89.6
# 2  Raju   65        98.7

# %% [markdown]
# <h3 style = "color:Blue">Creation of DataFrame from list of dictionaries</h3>

# %%
list1 = [{"Name":"Ramu", "Age":35, "Percentage":67.5}, {"Name":"Rani", "Age":45, "Percentage":89.6}, {"Name":"Raju", "Age":65, "Percentage":98.7}]
# Each dictionary in the list will become a row in the dataframe

df2 = pd.DataFrame(list1)

print(df2)
# Out:
#    Name  Age  Percentage
# 0  Ramu   35        67.5
# 1  Rani   45        89.6
# 2  Raju   65        98.7

# %% [markdown]
# <h3 style = "color:Blue">Creation of a DataFrame from list of lists</h3>

# %%
list2 = [[10, 100, 1000], [20, 200, 2000]] 
# Each inner list will be a row in the dataframe

df2 = pd.DataFrame(list2)

print(df2)
# Out:
#     0    1     2
# 0  10  100  1000
# 1  20  200  2000

# %%
# Assigning row indexes and column names while creating a dataframe
df22 = pd.DataFrame(list2, index = ['a','b'], columns = ["Tens", "Hundrads", "Thousands"])

print(df22)
# Out:
#    Tens  Hundrads  Thousands
# a    10       100       1000
# b    20       200       2000

# %%
# Changing the labels for rows and columns
df2.index = ["r1", "r2"]
df2.columns = ["10s", "100s", "1000s"]

print(df2)
# Out:
#     10s  100s  1000s
# r1   10   100   1000
# r2   20   200   2000

# %% [markdown]
# <h2 style = "color:Green">Working with CSV files</h2>
#
#
# * CSV --> Comma Separated Values

# %% [markdown]
# <h3 style = "color:Blue">Importing CSV file to a DataFrame</h3>
#
#
#
# * **pandas.read_csv(path)**: Function to create a DataFrame from a csv file.

# %%
df3 = pd.read_csv(r"c:\Users\admin\Desktop\Employee1.csv")
print(df3)
# Out:
#       ID      Name Department  Salary
# 0  ID001    Kishor        ECE    5000
# 1  ID002     Bhanu        CSE    4000
# 2  ID003  Srikanth         IT    4500
# 3  ID004    Harish         ME    2000

# %% [markdown]
# * **pandas.read_csv(path, names = [list_of_column_names])** : names keyword argument can be used when file is not having header.

# %%
df4 = pd.read_csv(r"c:\Users\admin\Desktop\Employee2.csv", names = ["ID", "Name", "Department", "Salary"])
print(df4)
# Out:
#       ID      Name Department  Salary
# 0  ID001    Kishor        ECE    5000
# 1  ID002     Bhanu        CSE    4000
# 2  ID003  Srikanth         IT    4500
# 3  ID004    Harish         ME   42000

# %% [markdown]
# <h3 style = "color:Blue">Exporting DataFrame to a CSV file</h3>
#
#
# * **pandas.DataFrame.to_csv(path)**: Copies the contents with row index to a csv file specified by path.

# %%
df4.to_csv(r"c:\Users\admin\Desktop\Employee3.csv")

# %% [markdown]
# * **pandas.DataFrame.to_csv(path, index = False)**: Copies the contents without row index to a csv file specified by path.

# %%
df4.to_csv(r"c:\Users\admin\Desktop\Employee4.csv", index = False)
